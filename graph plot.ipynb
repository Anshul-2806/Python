# %%
print(2+3)
# print("anshul" + 28)
print("hello" + "python")
# Out:
# 5
# hellopython

# %%
import numpy as np

# %%
n = np.array([[4,5,6,7], [9,7,8,3]])
print(n.sum())
print(n.dtype)
# Out:
# 49
# int32

# %%
import seaborn as sb
import matplotlib.pyplot as mt

# %%
data = {'a':[1,2,3,4,5],
       'b':[2,3,5,7,11]}

# create scatter plot
sb.scatterplot(x='a', y='b', data=data)

# add titles and labels
mt.title('Scatter Plot Example')
mt.xlabel('X-axis')
mt.ylabel('Y-axis')

# show the plot
mt.show()

# %%
import matplotlib.pyplot as mt
nm = ['anshul', 'vitata', 'ananyo', 'vishakha']
marks = [89, 85, 78, 95]
mt.bar(nm, marks, color='red')
# mp.title('Bar Plot')
# mp.xlabel('name')
# mp.ylabel('marks')
mp.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 8
#       4 mt.bar(nm, marks, color='red')
#       5 # mp.title('Bar Plot')
#       6 # mp.xlabel('name')
#       7 # mp.ylabel('marks')
# ----> 8 mp.show()
#
# NameError: name 'mp' is not defined

# %%
x = [1,2,3]
y = [2,4,1]
mt.plot(x,y)
mt.xlabel('X-axis')
mt.ylabel('Y-axis')
mt.title('Graph')
mt.show()

# %%
# line 1 points
x1 = [1,2,3]
y1 = [2,4,1]
# plotting the line 1 points 
mt.plot(x1, y1, label = "line 1")

# line 2 points
x2 = [1,2,3]
y2 = [4,1,3]
# plotting the line 2 points 
mt.plot(x2, y2, label = "line 2")

# naming the x axis
mt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
# giving a title to my graph
mt.title('Two lines on same graph!')

# show a legend on the plot
mt.legend()

# function to show the plot
mt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 16
#      14 mt.xlabel('x - axis')
#      15 # naming the y axis
# ---> 16 plt.ylabel('y - axis')
#      17 # giving a title to my graph
#      18 mt.title('Two lines on same graph!')
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# x axis values
x = [1,2,3,4,5,6]
# corresponding y axis values
y = [2,4,1,5,2,6]

# plotting the points 
plt.plot(x, y, color='green', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='blue', markersize=10)

# setting x and y axis range
plt.ylim(1,8)
plt.xlim(1,8)

# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')

# giving a title to my graph
plt.title('Some cool customizations!')

# function to show the plot
plt.show()

# %%
nm = ['ansh', 'vishi']
age = [23,21]
plt.plot(nm,age)
plt.show()

# %%
# defining labels
activities = ['eat', 'sleep', 'work', 'play']

# portion covered by each label
slices = [3, 7, 8, 6]

# color for each label
colors = ['r', 'y', 'g', 'b']

# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors, startangle=90, shadow = True, explode = (0, 0, 0.1, 0),radius = 1.2, autopct = '%1.1f%%')

# plotting legend
plt.legend()

# showing the plot
plt.show()

# %%
# importing the required modules
print('matplotlib, numpy')

# setting the x - coordinates
x = np.arange(0, 2*(np.pi), 0.1)
# setting the corresponding y - coordinates
y = np.sin(x)

# plotting the points
plt.plot(x, y)

# function to show the plot
plt.show()
# Out:
# matplotlib, numpy
